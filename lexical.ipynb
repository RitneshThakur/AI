# %% [markdown]
# <a href="https://colab.research.google.com/github/RitneshThakur/AI/blob/main/lexical.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk import pos_tag
import matplotlib.pyplot as plt
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')

# Example textabs
text = "Lexical analysis helps in breaking sentences into tokens. These tokens can be words or punctuation marks."
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
sentences = sent_tokenize(text)
print("Sentence Tokenization:")
print(sentences)

# Word tokenization
words = word_tokenize(text)
print("\nWord Tokenization:")
print(words)
# Out:
# Sentence Tokenization:
# ['Lexical analysis helps in breaking sentences into tokens.', 'These tokens can be words or punctuation marks.']
#
# Word Tokenization:
# ['Lexical', 'analysis', 'helps', 'in', 'breaking', 'sentences', 'into', 'tokens', '.', 'These', 'tokens', 'can', 'be', 'words', 'or', 'punctuation', 'marks', '.']

# %%
# Part-of-Speech (POS) tagging
pos_tags = pos_tag(words)
print("\nPart-of-Speech (POS) Tagging:")
print(pos_tags)


freq_dist = nltk.FreqDist(words)

plt.figure(figsize=(10, 6))
freq_dist.plot(20, title="Word Frequency Distribution")
plt.show()
# Out:
# Part-of-Speech (POS) Tagging:
# [('Lexical', 'JJ'), ('analysis', 'NN'), ('helps', 'VBZ'), ('in', 'IN'), ('breaking', 'VBG'), ('sentences', 'NNS'), ('into', 'IN'), ('tokens', 'NNS'), ('.', '.'), ('These', 'DT'), ('tokens', 'NNS'), ('can', 'MD'), ('be', 'VB'), ('words', 'NNS'), ('or', 'CC'), ('punctuation', 'NN'), ('marks', 'NNS'), ('.', '.')]
